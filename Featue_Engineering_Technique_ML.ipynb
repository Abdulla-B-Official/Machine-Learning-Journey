# %% [markdown]
# ## Feature Engineering
# Whatever you do wih features, we call it as Feature Engineering.
#
# * Feature Elimination - dropping the features.
# * Feature Addition - adding some features.
# * Feature Transformation - transforming the given feature values into an another scale - Log Tranformation, Sqrt Transformation ..
# * Feature Selection - deciding which features are important out of many features and choosing that features for model building.
#
# ## Feature Selection Techniques
#
# * sklearn - SelectFromModel
# * sklearn - RFE(ie,Recursive Feature Elimination)

# %% [markdown]
# ## 1. Import Necessary Libraries

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE,SelectFromModel
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Import Dataset

# %%
breast_cancer_data=load_breast_cancer()
X=breast_cancer_data.data
y=breast_cancer_data.target

# %% [markdown]
# ## 3. Data Understanding

# %%
X.shape,y.shape
# Out:
# ((569, 30), (569,))

# %% [markdown]
# ## 4. Model Building

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.20,shuffle=True,stratify=y)

# %%
X_train.shape,X_test.shape
# Out:
# ((455, 30), (114, 30))

# %%
y_train.shape,y_test.shape
# Out:
# ((455,), (114,))

# %% [markdown]
# ## 5. Model Training || 6. Model Testing || 7.Model Evaluation

# %%
rf_model=RandomForestClassifier(max_depth=7,random_state=123)
rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)
print("accuracy_score :",round(accuracy_score(y_test,y_pred),4))
print("precision_score :",round(precision_score(y_test,y_pred),4))
print("recall_score :",round(recall_score(y_test,y_pred),4))
print("confusion_matrix : \n",confusion_matrix(y_test,y_pred))
# Out:
# accuracy_score : 0.9649
# precision_score : 0.9474
# recall_score : 1.0
# confusion_matrix :
#  [[38  4]
#  [ 0 72]]

# %%
rf_model.feature_importances_
# Out:
# array([0.03425079, 0.01352402, 0.04730201, 0.03544731, 0.00607816,
#        0.01542646, 0.05808408, 0.12146301, 0.00332284, 0.00634759,
#        0.00901207, 0.00306766, 0.01430998, 0.05126081, 0.00305035,
#        0.00321258, 0.00487383, 0.00510048, 0.00415245, 0.0052961 ,
#        0.11728533, 0.01399996, 0.13768637, 0.11574642, 0.00884484,
#        0.01448523, 0.01980776, 0.11056881, 0.0086284 , 0.00836431])

# %% [markdown]
# ## 1st Technique select_from_model

# %%
select_from_model=SelectFromModel( estimator=RandomForestClassifier(), max_features=15)
select_from_model.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(), max_features=15)

# %%
select_from_model.get_support()
# Out:
# array([ True, False,  True,  True, False, False,  True,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False,  True,  True, False, False,  True,
#         True, False, False])

# %%
breast_cancer_data.feature_names[select_from_model.get_support()]
# Out:
# array(['mean radius', 'mean perimeter', 'mean area', 'mean concavity',
#        'mean concave points', 'worst radius', 'worst perimeter',
#        'worst area', 'worst concavity', 'worst concave points'],
#       dtype='<U23')

# %%
len(breast_cancer_data.feature_names[select_from_model.get_support()])
# Out:
# 10

# %%
X_train_select_from_model=select_from_model.transform(X_train)
X_test_select_from_model=select_from_model.transform(X_test)

# %%
def runRandomForestClassifier(X_train, X_test, y_train, y_test):
    rf_model=RandomForestClassifier(max_depth=7,random_state=123)
    rf_model.fit(X_train,y_train)
    y_pred=rf_model.predict(X_test)
    print("accuracy_score :",round(accuracy_score(y_test,y_pred),4))
    print("precision_score :",round(precision_score(y_test,y_pred),4))
    print("recall_score :",round(recall_score(y_test,y_pred),4))
    print("confusion_matrix : \n",confusion_matrix(y_test,y_pred))

# %%
# %%time
runRandomForestClassifier(X_train, X_test, y_train, y_test)
# Out:
# accuracy_score : 0.9649
# precision_score : 0.9474
# recall_score : 1.0
# confusion_matrix :
#  [[38  4]
#  [ 0 72]]
# CPU times: total: 172 ms
# Wall time: 161 ms

# %%
# %%time
runRandomForestClassifier(X_train_select_from_model, X_test_select_from_model, y_train, y_test)
# Out:
# accuracy_score : 0.9474
# precision_score : 0.9459
# recall_score : 0.9722
# confusion_matrix :
#  [[38  4]
#  [ 2 70]]
# CPU times: total: 156 ms
# Wall time: 137 ms

# %% [markdown]
# ## 2nd Technique RFE(Recursive Feature Elimination)

# %%
rfe_model=RFE(estimator=RandomForestClassifier(),n_features_to_select=12,)
rfe_model.fit(X_train,y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=12)

# %%
rfe_model.get_support()
# Out:
# array([False, False,  True,  True, False, False,  True,  True, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False,  True,  True,  True,  True,  True, False,  True,
#         True, False, False])

# %%
len(breast_cancer_data.feature_names[rfe_model.get_support()])
# Out:
# 12

# %%
X_train_rfe_model= rfe_model.transform(X_train)

# %%
X_test_rfe_model= rfe_model.transform(X_test)

# %%
X_train_rfe_model.shape,X_test_rfe_model.shape
# Out:
# ((455, 12), (114, 12))

# %%
# %%time
runRandomForestClassifier(X_train, X_test, y_train, y_test) #30 feature
# Out:
# accuracy_score : 0.9649
# precision_score : 0.9474
# recall_score : 1.0
# confusion_matrix :
#  [[38  4]
#  [ 0 72]]
# CPU times: total: 172 ms
# Wall time: 178 ms

# %%
# %%time
runRandomForestClassifier(X_train_rfe_model, X_test_rfe_model, y_train, y_test) #12 feature
# Out:
# accuracy_score : 0.9649
# precision_score : 0.9595
# recall_score : 0.9861
# confusion_matrix :
#  [[39  3]
#  [ 1 71]]
# CPU times: total: 141 ms
# Wall time: 139 ms

# %% [markdown]
# ## 3. Take the important Features from GradientBoosting and train in within RandomForest Algorithm

# %%
rfe_model=RFE(estimator=GradientBoostingClassifier(),n_features_to_select=12,)
rfe_model.fit(X_train,y_train)
# Out:
# RFE(estimator=GradientBoostingClassifier(), n_features_to_select=12)

# %%
rfe_model.get_support()
# Out:
# array([False,  True, False, False, False, False,  True,  True, False,
#        False, False, False,  True,  True, False, False, False, False,
#        False,  True, False,  True,  True,  True, False, False,  True,
#         True, False,  True])

# %%
len(breast_cancer_data.feature_names[rfe_model.get_support()])
# Out:
# 12

# %%
X_train_rfe_model= rfe_model.transform(X_train)

# %%
X_test_rfe_model= rfe_model.transform(X_test)

# %%
X_train_rfe_model.shape,X_test_rfe_model.shape
# Out:
# ((455, 12), (114, 12))

# %%
# %%time
runRandomForestClassifier(X_train, X_test, y_train, y_test) #30 feature
# Out:
# accuracy_score : 0.9649
# precision_score : 0.9474
# recall_score : 1.0
# confusion_matrix :
#  [[38  4]
#  [ 0 72]]
# CPU times: total: 172 ms
# Wall time: 161 ms

# %%
# %%time
runRandomForestClassifier(X_train_rfe_model, X_test_rfe_model, y_train, y_test) #12 feature
# Out:
# accuracy_score : 0.9386
# precision_score : 0.9452
# recall_score : 0.9583
# confusion_matrix :
#  [[38  4]
#  [ 3 69]]
# CPU times: total: 156 ms
# Wall time: 153 ms

# %% [markdown]
# ## 4. How to choose the optimal number of features to train my model

# %%
for i in range(1,31):
     rfe_model=RFE(estimator=GradientBoostingClassifier(),n_features_to_select=i,)
     rfe_model.fit(X_train,y_train)
     X_train_rfe_model= rfe_model.transform(X_train)
     X_test_rfe_model= rfe_model.transform(X_test)
     print("selected Features",i)
     runRandomForestClassifier(X_train_rfe_model, X_test_rfe_model, y_train, y_test) #12 feature
     print("******************************")
# Out:
# selected Features 1
# accuracy_score : 0.886
# precision_score : 0.8933
# recall_score : 0.9306
# confusion_matrix :
#  [[34  8]
#  [ 5 67]]
# ******************************
# selected Features 2
# accuracy_score : 0.9035
# precision_score : 0.9178
# recall_score : 0.9306
# confusion_matrix :
#  [[36  6]
#  [ 5 67]]
# ******************************
# selected Features 3
# accuracy_score : 0.9298
# precision_score : 0.9324
# recall_score : 0.9583
# confusion_matrix :
#  [[37  5]
#  [ 3 69]]
# ******************************
# selected Features 4
# accuracy_score : 0.9386
# precision_score : 0.9452
# recall_score : 0.9583
# confusion_matrix :
#  [[38  4]
#  [ 3 69]]
# ******************************
# selected Features 5
# accuracy_score : 0.9474
# precision_score : 0.9459
# recall_score : 0.9722
# confusion_matrix :
#  [[38  4]
#  [ 2 70]]
# ******************************
# selected Features 6
# accuracy_score : 0.9298
# precision_score : 0.9324
# recall_score : 0.9583
# ...

# %% [markdown]
# ## We found 15 is the optimal number of features

# %%
rfe_model=RFE(estimator=GradientBoostingClassifier(),n_features_to_select=22,)
rfe_model.fit(X_train,y_train)
# Out:
# RFE(estimator=GradientBoostingClassifier(), n_features_to_select=22)

# %%
rfe_model.get_support()
# Out:
# array([False,  True,  True,  True, False,  True,  True,  True, False,
#        False,  True,  True,  True,  True,  True,  True, False, False,
#        False,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True])

# %%
len(breast_cancer_data.feature_names[rfe_model.get_support()])
# Out:
# 22

# %%
X_train_rfe_model= rfe_model.transform(X_train)

# %%
X_test_rfe_model= rfe_model.transform(X_test)

# %%
X_train_rfe_model.shape,X_test_rfe_model.shape
# Out:
# ((455, 22), (114, 22))

# %%
# %%time
runRandomForestClassifier(X_train, X_test, y_train, y_test) #30 feature
# Out:
# accuracy_score : 0.9649
# precision_score : 0.9474
# recall_score : 1.0
# confusion_matrix :
#  [[38  4]
#  [ 0 72]]
# CPU times: total: 141 ms
# Wall time: 166 ms

# %%
# %%time
runRandomForestClassifier(X_train_rfe_model, X_test_rfe_model, y_train, y_test) #12 feature
# Out:
# accuracy_score : 0.9474
# precision_score : 0.9459
# recall_score : 0.9722
# confusion_matrix :
#  [[38  4]
#  [ 2 70]]
# CPU times: total: 172 ms
# Wall time: 173 ms

# %% [markdown]
# # THE END
